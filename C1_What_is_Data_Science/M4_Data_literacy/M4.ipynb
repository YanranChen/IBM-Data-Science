# %% [markdown]
# # Metadata
# Types of Metadata:
#  - Technical metadata
#     - defines the data structures in data repositories or platforms, primarily from a technical perspective
#     - typically stored in specialized tables in the database called the System Catalog
#  - Process metadata
#      - describes the processes that operate behind business systems such as data warehouses, accounting systems, or customer relationship management tools
#  - Business metadata
#      - information about the data described in readily interpretable ways
#      - for business-minded users to find data which is meaningful and valuable to them and know where that data can be accessed from
#
# ### Quiz
# ![alt text](M4-Practice-Quiz-Metadata.png)
#
# <details>
#   <summary>Click for Answer</summary>
#
# ![alt text](M4-Practice-Quiz-Metadata-ans_1.png)
# ![alt text](M4-Practice-Quiz-Metadata-ans_2.png)
#
# </details>

# %% [markdown]
# ## Different forms of data
# ### Structured
#
# ### Semi-structured
#  - some organizational propertys
#  - lacks fixed or rigid schema
#  - cannot be stored in rows and columns
#  - contains tags and elements, or metadata
#
# ### Unstructured
#  - image, map, etc
#
# ### Quiz - Understanding Data
# ![alt text](M4-Practice-Quiz-Understanding-Data.png)
# <details>
#     <summary>Click for Answer</summary>
#
# ![alt text](M4-Practice-Quiz-Understanding-Data-ans_1.png)
# ![alt text](M4-Practice-Quiz-Understanding-Data-ans_2.png)
#
# </details>

# %% [markdown]
# ## Data Collection and Organization
# ### Data repository
# #### Types of data repositories
# - Database
# - Data warehouse (ETL)
#     - Relational database (SQL)
#     - Non-relational database (NoSQL)
# - Big data stores
#
# ### Relational Database
# A relational database is a collection of data organized into a table structure, where the tables can be linked, or related, based on data common to each.
#
# Cloud-based (Database-as-a-service)
#
# - Create meaningful information by joining tables
# - Flexibility to make changes while dtabase is in use
# - Minimize data redundancy by allowing relationships to be defined
# - Offer export and import options that provide ease of backup disaster recovery
# - ACID compliant
#
# Use cases
#  - Online Transaction Processing (OLTP)
#  - Data Warehouse (OLAP)
#
# Does not work well with semi-structured and unstructured data. Thus, not suitable for for extensive analytics on such data
#
# ### NoSQL (Not only SQL)
# Types of NoSQL databases:
# - Key-value store
# - Document-based
# - Column-based
# - Graph-based
#
# ### Data warehouse
# A data warehouse is a multi-purpose enabler of operational and performance analytics.
# Data warehouses:
# - Store current and historical data that has been cleansed, conformed, and categorized
#
# ### Data mart
# A data mart is a sub-section of the data warehouse, built specifically for a particular business function, purpose, or community of users. The idea is to provide stakeholders data that is most relevant to them, when they need it.
# Data marts:
# - Provide analytical capabilities for a restricted area of the data warehouss
# - Offer isolated security and isolated performance
# - The most important role of a data mart is business-specific reporting and analytics
#
# ### Data lake
# ![alt text](data_lakes.png)
# A data lake is a storage repository that can store large amounts of structured, semi-structured, and unstructured data in their native format, classified and tagged with metadata.
# So, while a data warehouse stores data processed for a specific need, a data lake is a pool of raw data where each data element is given a unique identifier and is tagged with metatags for further use.
# - Retain all source data, without any exclusions
# - The most important role of a data lake is in predictive and advanced analytics.
#
# ### Extract, Transform and Load (ETL)
